# %% [markdown]
# API stands for Application Programming Interface

# %% [markdown]
# API helps two softwares to communicate with each other. API can be thought of a data pipeline.

# %% [markdown]
# API helps multiple platforms to communicate with the same database to maintain integrity of data

# %%
import requests

url = "https://movies-ratings2.p.rapidapi.com/ratings"

querystring = {"id":"tt0111161"}

headers = {
	"x-rapidapi-key": "d0bdd61768msha6c4b9ae10907afp17f3a9jsnfd41772091ac",
	"x-rapidapi-host": "movies-ratings2.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'tmdbId': 278, 'imdbId': 'tt0111161', 'lastUpdated': 1738173381282, 'ratings': {'imdb': {'score': 9.3, 'reviewsCount': 3000000, 'url': 'https://www.imdb.com/title/tt0111161/'}, 'metacritic': {'metascore': 82, 'userScore': 9.3, 'averageScore': 8.8, 'url': 'https://www.metacritic.com/movie/the-shawshank-redemption'}, 'rotten_tomatoes': {'tomatometer': 89, 'tomatometerReviewsCount': 146, 'audienceScore': 98, 'audienceScoreReviewsCount': 250000, 'averageScore': 9.4, 'url': 'https://www.rottentomatoes.com/m/shawshank_redemption'}, 'letterboxd': {'score': 4.6, 'url': 'https://letterboxd.com/film/the-shawshank-redemption'}, 'allocine': None, 'average': {'score': 9.12}}, 'media': {'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg', 'budget': 25000000, 'genres': [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name': 'Crime'}], 'homepage': '', 'id': 278, 'imdb_id': 'tt0111161', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'The Shawshank Redemption', 'overview': 'Imprisone
# ...

# %%
import pandas as pd 
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
# converts json to a dataframe
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     29.7884
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     64.7218
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     15.9648
# 3  The true story of how businessman Oskar Schind...   1993-12-15     18.9267
# 4  The defense and the prosecution have rested an...   1957-04-10     22.8832
#
#    vote_average  vote_count
# 0         8.710       28270
# 1         8.686       21429
# 2         8.570       12947
# 3         8.565       16418
# 4         8.547        9116

# %%
df=pd.DataFrame()

# %%
# the above one only fetched till page 1. we have 428 pages so bring them all in a loop
for i in range(1,2):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

    # add the dataframe
    df=pd.concat([df,temp_df],ignore_index=True)

# %%
df
# Out:
#          id                     title  \
# 0       278  The Shawshank Redemption
# 1       238             The Godfather
# 2       240     The Godfather Part II
# 3       424          Schindler's List
# 4       389              12 Angry Men
# ..      ...                       ...
# 755     346             Seven Samurai
# 756     769                GoodFellas
# 757  157336              Interstellar
# 758   12477    Grave of the Fireflies
# 759     637         Life Is Beautiful
#
#                                               overview release_date  \
# 0    Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1    Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2    In the continuing saga of the Corleone crime f...   1974-12-20
# 3    The true story of how businessman Oskar Schind...   1993-12-15
# 4    The defense and the prosecution have rested an...   1957-04-10
# ..                                                 ...          ...
# ...

# %%
# convert the dataframe to a csv file
df.to_csv('movies.csv')
