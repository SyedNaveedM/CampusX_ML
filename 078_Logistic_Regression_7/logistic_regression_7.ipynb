# %% [markdown]
# ### Polynomial Logistic Regression

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Works for data where we have non-linear decision boundaries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
