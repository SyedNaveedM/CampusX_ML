# %% [markdown]
# # 📘 Derivative of the Sigmoid Function
#
# ---
#
# ## 🧠 Definition of Sigmoid Function
#
# The sigmoid (logistic) function is defined as:
#
# ```math
# σ(x) = \frac{1}{1 + e^{-x}}
# ```
#
# It maps any real number to the range (0, 1).
#
# ---
#
# ## 🎯 Goal
#
# Find the derivative:
#
# ```math
# \frac{dσ(x)}{dx}
# ```
#
# ---
#
# ## 🔄 Step-by-Step Derivation
#
# ### Step 1: Rewrite σ(x) for differentiation
#
# Let:
#
# ```math
# σ(x) = y = \frac{1}{1 + e^{-x}}
# ```
#
# Differentiate y with respect to x:
#
# ```math
# \frac{dy}{dx} = \frac{d}{dx} \left[\frac{1}{1 + e^{-x}}\right]
# ```
#
# ---
#
# ### Step 2: Use the chain rule and quotient rule
#
# Let:
#
# * `u(x) = 1`
# * `v(x) = 1 + e^{-x}`
#
# Then using the quotient rule:
#
# ```math
# \frac{dy}{dx} = \frac{v \cdot \frac{du}{dx} - u \cdot \frac{dv}{dx}}{v^2}
# ```
#
# Since:
#
# * `du/dx = 0`
# * `dv/dx = -e^{-x}`
#
# We get:
#
# ```math
# \frac{dy}{dx} = \frac{0 - (1)(-e^{-x})}{(1 + e^{-x})^2} = \frac{e^{-x}}{(1 + e^{-x})^2}
# ```
#
# ---
#
# ### Step 3: Express in terms of σ(x)
#
# Recall:
#
# ```math
# σ(x) = \frac{1}{1 + e^{-x}} \Rightarrow 1 - σ(x) = \frac{e^{-x}}{1 + e^{-x}}
# ```
#
# Now multiply:
#
# ```math
# σ(x) (1 - σ(x)) = \left(\frac{1}{1 + e^{-x}}\right) \left(\frac{e^{-x}}{1 + e^{-x}}\right) = \frac{e^{-x}}{(1 + e^{-x})^2}
# ```
#
# Which matches our earlier result.
#
# ---
#
# ## ✅ Final Result
#
# ```math
# \frac{dσ(x)}{dx} = σ(x)(1 - σ(x))
# ```
#
# ---
#
# ## 🧪 Example
#
# If `x = 0`:
#
# ```math
# σ(0) = \frac{1}{1 + 1} = 0.5 \\
# \frac{dσ(0)}{dx} = 0.5(1 - 0.5) = 0.25
# ```
#
# ---
#
# ## 📌 Summary
#
# * The sigmoid derivative is compact and elegant.
# * It only depends on the output of the sigmoid itself.
# * Very efficient in neural network backpropagation.
