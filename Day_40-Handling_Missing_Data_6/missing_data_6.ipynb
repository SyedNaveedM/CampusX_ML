# %% [markdown]
# MICE - Multivariate Imputation by Chained Equations

# %% [markdown]
# Assumptions:
# 1) MCAR - Missing Completely At Random
# 2) MAR - Missing At Random (we can fill the data using the data from the other columns)
# 3) MNAR - Missing Not At Random
#
# We use MICE only when we MAR data. It is very accurate but it is very slow

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Algorithm

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Move from left to right

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Stage 1 done till here

# %% [markdown]
# Keep doing this till the difference limit to 0.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
