# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Same as binary class accuracy

# %% [markdown]
# How much accuracy our model should have is completely dependent on our problem statement and what it needs to do

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# It doesn't tell us what type of mistakes our model is making, false positives or false negatives

# %% [markdown]
# This problem is solved using confusion matrix

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# It tells us the type of the errors clearly

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Type 1 - False Positive
#
# Type 2 - False Negative

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Accuracy is misleading when the dataset is very imbalanced. So, if it is something rare, then even a simple model such as predicting the major class gives it 99% accuracy which is very misleading
